# %% [markdown]
# # PROJECT

# %% [markdown]
# ## Imoprting Required libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## step--1 : Reading and Understanding Data:

# %%
data_train = pd.read_csv('train.csv')

# %%
data_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data_train.shape
# Out:
# (1460, 81)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data_test = pd.read_csv('test.csv')

# %%
data_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
data_test.shape
# Out:
# (1459, 80)

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %% [markdown]
# ## step--2 : Checking and Treating Missing Values:

# %%
data_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data_test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
# dropping unnecessary columns:

data_train = data_train.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1)
data_test = data_test.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1)

# %%
data_train.shape
# Out:
# (1460, 77)

# %%
data_test.shape
# Out:
# (1459, 76)

# %% [markdown]
# ### Missing value treatment on train dataset:

# %%
data_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 77, dtype: object

# %%
# 1-handling missing value of numeric column on train dataset:

train_num = data_train.select_dtypes(include=[np.number])
train_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
# handling missing value with simple imputer:

from sklearn.impute import SimpleImputer

imputer= SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)

# %%
data_train.dtypes =='object'

df1= data_train.loc[:,data_train.dtypes != 'object']

numeric=imputer.fit_transform(df1)

numeric1=pd.DataFrame(numeric)
numeric1.columns = train_num.columns
numeric1.head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0        60.0         65.0   8450.0          7.0          5.0     2003.0
# 1  2.0        20.0         80.0   9600.0          6.0          8.0     1976.0
# 2  3.0        60.0         68.0  11250.0          7.0          5.0     2001.0
# 3  4.0        70.0         60.0   9550.0          7.0          5.0     1915.0
# 4  5.0        60.0         84.0  14260.0          8.0          5.0     2000.0
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0        2003.0       196.0       706.0  ...         0.0         61.0
# 1        1976.0         0.0       978.0  ...       298.0          0.0
# 2        2002.0       162.0       486.0  ...         0.0         42.0
# 3        1970.0         0.0       216.0  ...         0.0         35.0
# 4        2000.0       350.0       655.0  ...       192.0         84.0
#
# ...

# %%
# 2-handling missing value of category column on train dataset:

train_cat = data_train.select_dtypes(include=[np.object])
train_cat.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0      CollgCr       Norm       Norm  ...          Gd        Typ         NaN
# 1      Veenker      Feedr       Norm  ...          TA        Typ          TA
# 2      CollgCr       Norm       Norm  ...          Gd        Typ          TA
# 3      Crawfor       Norm       Norm  ...          Gd        Typ          Gd
# 4      NoRidge       Norm       Norm  ...          Gd        Typ          TA
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

df2=data_train.loc[:,data_train.dtypes=='object']
 
category = imputer.fit_transform(df2)

category1 = pd.DataFrame(category)
category1.columns = train_cat.columns
category1.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0      CollgCr       Norm       Norm  ...          Gd        Typ          Gd
# 1      Veenker      Feedr       Norm  ...          TA        Typ          TA
# 2      CollgCr       Norm       Norm  ...          Gd        Typ          TA
# 3      Crawfor       Norm       Norm  ...          Gd        Typ          Gd
# 4      NoRidge       Norm       Norm  ...          Gd        Typ          TA
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %%
#concating two dataframe numeric and catagory of train dataset:-

train_df = pd.concat([numeric1,category1], axis=1)
train_df.head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0        60.0         65.0   8450.0          7.0          5.0     2003.0
# 1  2.0        20.0         80.0   9600.0          6.0          8.0     1976.0
# 2  3.0        60.0         68.0  11250.0          7.0          5.0     2001.0
# 3  4.0        70.0         60.0   9550.0          7.0          5.0     1915.0
# 4  5.0        60.0         84.0  14260.0          8.0          5.0     2000.0
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  Functional  \
# 0        2003.0       196.0       706.0  ...           Gd         Typ
# 1        1976.0         0.0       978.0  ...           TA         Typ
# 2        2002.0       162.0       486.0  ...           Gd         Typ
# 3        1970.0         0.0       216.0  ...           Gd         Typ
# 4        2000.0       350.0       655.0  ...           Gd         Typ
#
# ...

# %%
train_df.shape
# Out:
# (1460, 77)

# %%
train_df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
#                 ..
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# SaleType         0
# SaleCondition    0
# Length: 77, dtype: int64

# %% [markdown]
# ### Missing value treatment on test dataset

# %%
data_test.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 76, dtype: object

# %%
# 1--handling missing value of numeric column on train dataset:

test_num = data_test.select_dtypes(include=[np.number])
test_num.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# 0       1961          1961         0.0       468.0  ...       730.0
# 1       1958          1958       108.0       923.0  ...       312.0
# 2       1997          1998         0.0       791.0  ...       482.0
# 3       1998          1998        20.0       602.0  ...       470.0
# 4       1992          1992         0.0       263.0  ...       506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
# handling missing value with simple imputer:

from sklearn.impute import SimpleImputer

imputer= SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)

# %%
data_test.dtypes =='object'

df1= data_test.loc[:,data_test.dtypes != 'object']

numeric=imputer.fit_transform(df1)
numeric1=pd.DataFrame(numeric)
numeric1.columns = test_num.columns
numeric1.head()
# Out:
#        Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461.0        20.0         80.0  11622.0          5.0          6.0
# 1  1462.0        20.0         81.0  14267.0          6.0          6.0
# 2  1463.0        60.0         74.0  13830.0          5.0          5.0
# 3  1464.0        60.0         78.0   9978.0          6.0          6.0
# 4  1465.0       120.0         43.0   5005.0          8.0          5.0
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# 0     1961.0        1961.0         0.0       468.0  ...       730.0
# 1     1958.0        1958.0       108.0       923.0  ...       312.0
# 2     1997.0        1998.0         0.0       791.0  ...       482.0
# 3     1998.0        1998.0        20.0       602.0  ...       470.0
# 4     1992.0        1992.0         0.0       263.0  ...       506.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
# 2--handling missing value of catagory column in test dataset:-

test_cat= data_test.select_dtypes(include=[np.object])
test_cat.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RH   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4       RL   Pave      IR1         HLS    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0        NAmes      Feedr       Norm  ...          TA        Typ         NaN
# 1        NAmes       Norm       Norm  ...          Gd        Typ         NaN
# 2      Gilbert       Norm       Norm  ...          TA        Typ          TA
# 3      Gilbert       Norm       Norm  ...          Gd        Typ          Gd
# 4      StoneBr       Norm       Norm  ...          Gd        Typ         NaN
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

df2 = data_test.loc[:,data_test.dtypes=='object']

category =imputer.fit_transform(df2)
category1 =pd.DataFrame(category)
category1.columns = test_cat.columns
category1.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RH   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4       RL   Pave      IR1         HLS    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2  ... KitchenQual Functional FireplaceQu  \
# 0        NAmes      Feedr       Norm  ...          TA        Typ          Gd
# 1        NAmes       Norm       Norm  ...          Gd        Typ          Gd
# 2      Gilbert       Norm       Norm  ...          TA        Typ          TA
# 3      Gilbert       Norm       Norm  ...          Gd        Typ          Gd
# 4      StoneBr       Norm       Norm  ...          Gd        Typ          Gd
#
#   GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# ...

# %%
#concating two dataframe numeric and catagory of test dataset:-

test_df = pd.concat([numeric1,category1], axis=1)
test_df.head()
# Out:
#        Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461.0        20.0         80.0  11622.0          5.0          6.0
# 1  1462.0        20.0         81.0  14267.0          6.0          6.0
# 2  1463.0        60.0         74.0  13830.0          5.0          5.0
# 3  1464.0        60.0         78.0   9978.0          6.0          6.0
# 4  1465.0       120.0         43.0   5005.0          8.0          5.0
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 0     1961.0        1961.0         0.0       468.0  ...           TA
# 1     1958.0        1958.0       108.0       923.0  ...           Gd
# 2     1997.0        1998.0         0.0       791.0  ...           TA
# 3     1998.0        1998.0        20.0       602.0  ...           Gd
# 4     1992.0        1992.0         0.0       263.0  ...           Gd
#
#    Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  GarageCond  \
# ...

# %%
test_df.shape
# Out:
# (1459, 76)

# %%
test_df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
#                 ..
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# SaleType         0
# SaleCondition    0
# Length: 76, dtype: int64

# %% [markdown]
# ## step--3 : Handling and Treating Outliers:

# %% [markdown]
# ### handling numeric column on train dataset:

# %%
train_cols = train_df.select_dtypes(include=[np.number])
train_cols.dtypes
# Out:
# Id               float64
# MSSubClass       float64
# LotFrontage      float64
# LotArea          float64
# OverallQual      float64
# OverallCond      float64
# YearBuilt        float64
# YearRemodAdd     float64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF         float64
# 2ndFlrSF         float64
# LowQualFinSF     float64
# GrLivArea        float64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath         float64
# HalfBath         float64
# BedroomAbvGr     float64
# KitchenAbvGr     float64
# TotRmsAbvGrd     float64
# Fireplaces       float64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF       float64
# OpenPorchSF      float64
# EnclosedPorch    float64
# 3SsnPorch        float64
# ScreenPorch      float64
# PoolArea         float64
# MiscVal          float64
# MoSold           float64
# YrSold           float64
# ...

# %%
corr = train_cols.corr().describe()

corr
# Out:
#               Id  MSSubClass  LotFrontage    LotArea  OverallQual  \
# count  38.000000   38.000000    38.000000  38.000000    38.000000
# mean    0.022858    0.013869     0.151438   0.117270     0.259510
# std     0.164321    0.205348     0.206943   0.183355     0.282679
# min    -0.050199   -0.357056    -0.357056  -0.139781    -0.183882
# 25%    -0.018682   -0.055879     0.037058   0.007031     0.030935
# 50%     0.000391   -0.009860     0.104539   0.081223     0.239295
# 75%     0.009940    0.038442     0.236706   0.178226     0.507570
# max     1.000000    1.000000     1.000000   1.000000     1.000000
#
#        OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  \
# count    38.000000  38.000000     38.000000   38.000000   38.000000  ...
# mean     -0.025192   0.169853      0.176536    0.168472    0.132043  ...
# std       0.199857   0.296608      0.245211    0.214354    0.251763  ...
# min      -0.375983  -0.387268     -0.193919   -0.127788   -0.495251  ...
# ...

# %%
train_num_cols = train_cols.columns
train_num_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
for i in train_num_cols:
    sns.boxplot(train_df[i])
    plt.show()

# %%
#capping outliers to 99 percentile on train dataset:-

def plot(x):
    sns.boxplot(train_df[x])
    plt.show()
    return

# %%
for x in train_num_cols:
    
    q3,q1 = np.percentile(train_df[x],[75,25])
    
    q4 = np.percentile(train_df[x],[99])
    
    train_df.loc[train_df[x] > q4[0], x] = q4[0]
    
    plot(x)

# %% [markdown]
# ### handling numeric column on test data set:

# %%
test_cols = test_df.select_dtypes(include=[np.number])
test_cols.dtypes
# Out:
# Id               float64
# MSSubClass       float64
# LotFrontage      float64
# LotArea          float64
# OverallQual      float64
# OverallCond      float64
# YearBuilt        float64
# YearRemodAdd     float64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF         float64
# 2ndFlrSF         float64
# LowQualFinSF     float64
# GrLivArea        float64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath         float64
# HalfBath         float64
# BedroomAbvGr     float64
# KitchenAbvGr     float64
# TotRmsAbvGrd     float64
# Fireplaces       float64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF       float64
# OpenPorchSF      float64
# EnclosedPorch    float64
# 3SsnPorch        float64
# ScreenPorch      float64
# PoolArea         float64
# MiscVal          float64
# MoSold           float64
# YrSold           float64
# ...

# %%
corr = test_cols.corr().describe()
corr
# Out:
#               Id  MSSubClass  LotFrontage    LotArea  OverallQual  \
# count  37.000000   37.000000    37.000000  37.000000    37.000000
# mean   -0.010515    0.005235     0.142348   0.142655     0.239082
# std     0.236364    0.216902     0.223844   0.217984     0.279301
# min    -0.974884   -0.425684    -0.425684  -0.359537    -0.161339
# 25%    -0.045966   -0.064357     0.012230   0.018030    -0.008764
# 50%    -0.017382   -0.012156     0.116001   0.099850     0.214906
# 75%     0.009201    0.040848     0.226795   0.188338     0.481842
# max     1.000000    1.000000     1.000000   1.000000     1.000000
#
#        OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  \
# count    37.000000  37.000000     37.000000   37.000000   37.000000  ...
# mean     -0.045327   0.183518      0.175977    0.175609    0.144908  ...
# std       0.203612   0.294121      0.255373    0.218067    0.258225  ...
# min      -0.361027  -0.363012     -0.243582   -0.144075   -0.459581  ...
# ...

# %%
test_num_cols = test_cols.columns
test_num_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')

# %%
for i in test_num_cols:
    sns.boxplot(test_df[i])
    plt.show()

# %%
#capping outliers to 99 percentile on test dataset:-

def plot(y):
    sns.boxplot(test_df[y])
    plt.show()
    return

# %%
for y in test_num_cols:
    
    q3,q1 = np.percentile(test_df[y],[75,25])
    
    q4 = np.percentile(test_df[y],[99])
    
    test_df.loc[test_df[y] > q4[0], y] = q4[0]
    
    plot(y)

# %% [markdown]
# ## step--4 : Data Analysis:

# %%
#1. univarient analysis:-

uni = list(train_df.describe().columns)

# %%
for i in uni:
    sns.displot(train_df[i])
    plt.show()

# %%
#2. biavarient analysis:-

plt.figure(figsize=(10,5))
sns.scatterplot(x=train_df['LotFrontage'], y=train_df['LotArea'])
plt.title('Correlations between Lot Area and Lot Frontage', size=15)
# Out:
# Text(0.5, 1.0, 'Correlations between Lot Area and Lot Frontage')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=train_df['MoSold'], y=train_df['YrSold'])
plt.suptitle('correlation between Monthly sold and yearly sold', size=15)
# Out:
# Text(0.5, 0.98, 'correlation between Monthly sold and yearly sold')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=train_df['YearBuilt'], y=train_df['SalePrice'], color='blue')
plt.suptitle('Year of construction and Price distribution', size=15)
# Out:
# Text(0.5, 0.98, 'Year of construction and Price distribution')

# %%
#3. multivarient analysis:-

plt.figure(figsize=(20,15))
sns.heatmap(train_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## step--5 : Data Preparation:

# %% [markdown]
# ### Converting categorical data into numerical on train dataset:-

# %%
train_cat_cols = train_df.select_dtypes(include=[np.object])
train_cat_cols.dtypes
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# SaleType         object
# ...

# %%
cols1 = train_cat_cols.columns
cols1
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Using label encoding on train dataset:-

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
train_df[cols1] = train_df[cols1].apply(le.fit_transform)

# %%
train_df.head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0        60.0         65.0   8450.0          7.0          5.0     2003.0
# 1  2.0        20.0         80.0   9600.0          6.0          8.0     1976.0
# 2  3.0        60.0         68.0  11250.0          7.0          5.0     2001.0
# 3  4.0        70.0         60.0   9550.0          7.0          5.0     1915.0
# 4  5.0        60.0         84.0  14260.0          8.0          5.0     2000.0
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  Functional  \
# 0        2003.0       196.0       706.0  ...            2           6
# 1        1976.0         0.0       978.0  ...            3           6
# 2        2002.0       162.0       486.0  ...            2           6
# 3        1970.0         0.0       216.0  ...            2           6
# 4        2000.0       350.0       655.0  ...            2           6
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   float64
#  1   MSSubClass     1460 non-null   float64
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   float64
#  4   OverallQual    1460 non-null   float64
#  5   OverallCond    1460 non-null   float64
#  6   YearBuilt      1460 non-null   float64
#  7   YearRemodAdd   1460 non-null   float64
#  8   MasVnrArea     1460 non-null   float64
#  9   BsmtFinSF1     1460 non-null   float64
#  10  BsmtFinSF2     1460 non-null   float64
#  11  BsmtUnfSF      1460 non-null   float64
#  12  TotalBsmtSF    1460 non-null   float64
#  13  1stFlrSF       1460 non-null   float64
#  14  2ndFlrSF       1460 non-null   float64
#  15  LowQualFinSF   1460 non-null   float64
#  16  GrLivArea      1460 non-null   float64
# ...

# %% [markdown]
# ### Converting categorical data into numerical on test dataset:

# %%
test_cat_cols = test_df.select_dtypes(include=[np.object])
test_cat_cols.dtypes
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# SaleType         object
# ...

# %%
cols2 = test_cat_cols.columns
cols2
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Using label encoding on test dataset:-

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
test_df[cols2] = test_df[cols2].apply(le.fit_transform)

# %%
test_df.head()
# Out:
#        Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461.0        20.0         80.0  11622.0          5.0          6.0
# 1  1462.0        20.0         81.0  14267.0          6.0          6.0
# 2  1463.0        60.0         74.0  13830.0          5.0          5.0
# 3  1464.0        60.0         78.0   9978.0          6.0          6.0
# 4  1465.0       120.0         43.0   5005.0          8.0          5.0
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  KitchenQual  \
# 0     1961.0        1961.0         0.0       468.0  ...            3
# 1     1958.0        1958.0       108.0       923.0  ...            2
# 2     1997.0        1998.0         0.0       791.0  ...            3
# 3     1998.0        1998.0        20.0       602.0  ...            2
# 4     1992.0        1992.0         0.0       263.0  ...            2
#
#    Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  GarageCond  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   float64
#  1   MSSubClass     1459 non-null   float64
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   OverallQual    1459 non-null   float64
#  5   OverallCond    1459 non-null   float64
#  6   YearBuilt      1459 non-null   float64
#  7   YearRemodAdd   1459 non-null   float64
#  8   MasVnrArea     1459 non-null   float64
#  9   BsmtFinSF1     1459 non-null   float64
#  10  BsmtFinSF2     1459 non-null   float64
#  11  BsmtUnfSF      1459 non-null   float64
#  12  TotalBsmtSF    1459 non-null   float64
#  13  1stFlrSF       1459 non-null   float64
#  14  2ndFlrSF       1459 non-null   float64
#  15  LowQualFinSF   1459 non-null   float64
#  16  GrLivArea      1459 non-null   float64
# ...

# %%
# setting saleprice column as target column:

x = train_df.drop(['SalePrice'], axis=1)
y= train_df['SalePrice']

# %%
x.shape
# Out:
# (1460, 76)

# %%
y.shape
# Out:
# (1460,)

# %% [markdown]
# ## step--6 : Train-Test-Split :

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.30, random_state=45)

# %%
x_train.shape
# Out:
# (1022, 76)

# %%
y_train.shape
# Out:
# (1022,)

# %%
x_test.shape
# Out:
# (438, 76)

# %%
y_test.shape
# Out:
# (438,)

# %% [markdown]
# ## Scaling:

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## step--7 : Fit The Model:

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict The Model:

# %%
y_pred = linear_model.predict(x_test)

# %% [markdown]
# ## step--8 : Evaluate The Model:

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8846280365388801
