# %% [markdown]
# ## EDA :

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # step:1 - reading and understanding data:

# %%
df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
df.shape
# Out:
# (801, 41)

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
data = df[['name','type1','type2','attack','defense','sp_attack','sp_defense','speed','generation','base_total','hp','is_legendary']]

# %%
data.head()
# Out:
#          name  type1   type2  attack  defense  sp_attack  sp_defense  speed  \
# 0   Bulbasaur  grass  poison      49       49         65          65     45
# 1     Ivysaur  grass  poison      62       63         80          80     60
# 2    Venusaur  grass  poison     100      123        122         120     80
# 3  Charmander   fire     NaN      52       43         60          50     65
# 4  Charmeleon   fire     NaN      64       58         80          65     80
#
#    generation  base_total  hp  is_legendary
# 0           1         318  45             0
# 1           1         405  60             0
# 2           1         625  80             0
# 3           1         309  39             0
# 4           1         405  58             0

# %%
data.shape
# Out:
# (801, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          801 non-null    object
#  1   type1         801 non-null    object
#  2   type2         417 non-null    object
#  3   attack        801 non-null    int64
#  4   defense       801 non-null    int64
#  5   sp_attack     801 non-null    int64
#  6   sp_defense    801 non-null    int64
#  7   speed         801 non-null    int64
#  8   generation    801 non-null    int64
#  9   base_total    801 non-null    int64
#  10  hp            801 non-null    int64
#  11  is_legendary  801 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 75.2+ KB

# %% [markdown]
# # step:2 - checking null values and treating:

# %%
data.isnull().sum()/len(data)*100
# Out:
# name             0.000000
# type1            0.000000
# type2           47.940075
# attack           0.000000
# defense          0.000000
# sp_attack        0.000000
# sp_defense       0.000000
# speed            0.000000
# generation       0.000000
# base_total       0.000000
# hp               0.000000
# is_legendary     0.000000
# dtype: float64

# %%
## checking column type 2:

data['type2'].describe()
# Out:
# count        417
# unique        18
# top       flying
# freq          95
# Name: type2, dtype: object

# %%
# treating null values:   #object are treated by mode and (int/float) with mean and median to fill null values. 

data.fillna(data['type2'].mode()[0], inplace = True)

# %%
data['type2'].describe()
# Out:
# count        801
# unique        18
# top       flying
# freq         479
# Name: type2, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          801 non-null    object
#  1   type1         801 non-null    object
#  2   type2         801 non-null    object
#  3   attack        801 non-null    int64
#  4   defense       801 non-null    int64
#  5   sp_attack     801 non-null    int64
#  6   sp_defense    801 non-null    int64
#  7   speed         801 non-null    int64
#  8   generation    801 non-null    int64
#  9   base_total    801 non-null    int64
#  10  hp            801 non-null    int64
#  11  is_legendary  801 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 75.2+ KB

# %%
data.describe()
# Out:
#            attack     defense   sp_attack  sp_defense       speed  generation  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000  801.000000
# mean    77.857678   73.008739   71.305868   70.911361   66.334582    3.690387
# std     32.158820   30.769159   32.353826   27.942501   28.907662    1.930420
# min      5.000000    5.000000   10.000000   20.000000    5.000000    1.000000
# 25%     55.000000   50.000000   45.000000   50.000000   45.000000    2.000000
# 50%     75.000000   70.000000   65.000000   66.000000   65.000000    4.000000
# 75%    100.000000   90.000000   91.000000   90.000000   85.000000    5.000000
# max    185.000000  230.000000  194.000000  230.000000  180.000000    7.000000
#
#        base_total          hp  is_legendary
# count  801.000000  801.000000    801.000000
# mean   428.377029   68.958801      0.087391
# std    119.203577   26.576015      0.282583
# min    180.000000    1.000000      0.000000
# ...

# %%
# checking outliers on numeric columns:

numeric_col = ['attack','defense','sp_attack','sp_defense','speed','generation','base_total','hp','is_legendary']

for i in numeric_col:
    sns.boxplot(data[i])
    plt.show()

# %%
# treating outliers:

def plot(x):
    sns.boxplot(data[x])
    plt.show()
    return

# %%
for x in numeric_col:
    
    q3,q1 = np.percentile(data[x],[75,25])
    
    q4 = np.percentile(data[x],[99])
    
    data.loc[data[x]>q4[0],x]=q4[0]
    
    plot(x)

# %% [markdown]
# # step:3 - data analysis:

# %%
# 1 - univariate analysis:

uni = list(data.describe().columns)
uni
# Out:
# ['attack',
#  'defense',
#  'sp_attack',
#  'sp_defense',
#  'speed',
#  'generation',
#  'base_total',
#  'hp',
#  'is_legendary']

# %%
for i in uni:
    sns.displot(data[i])
    plt.show()

# %%
# 2 - bivariate analysis:

sns.pairplot(data)

# %%
# to compare two features:

data.plot.scatter('sp_attack','sp_defense')
# Out:
# <AxesSubplot:xlabel='sp_attack', ylabel='sp_defense'>

# %%
# 3 - multivariate analysis:

sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
h_map = data.corr()
h_map
# Out:
#                 attack   defense  sp_attack  sp_defense     speed  generation  \
# attack        1.000000  0.486321   0.366830    0.282727  0.354685    0.102291
# defense       0.486321  1.000000   0.265427    0.533134  0.024125    0.068663
# sp_attack     0.366830  0.265427   1.000000    0.528775  0.439901    0.072859
# sp_defense    0.282727  0.533134   0.528775    1.000000  0.241979    0.054365
# speed         0.354685  0.024125   0.439901    0.241979  1.000000   -0.018862
# generation    0.102291  0.068663   0.072859    0.054365 -0.018862    1.000000
# base_total    0.728834  0.648221   0.738063    0.730635  0.549157    0.086992
# hp            0.476240  0.307832   0.408210    0.404030  0.190229    0.085690
# is_legendary  0.300220  0.277779   0.401379    0.343818  0.309275    0.139029
#
#               base_total        hp  is_legendary
# attack          0.728834  0.476240      0.300220
# defense         0.648221  0.307832      0.277779
# ...
